# %%
# !python ../EDA_OpenEnv_Agent/inference.py --csv ../data/sample_sales_data.csv
# Out:
# Traceback (most recent call last):
#   File "c:\Users\rahma\OneDrive\Documents\GitHub\Streamlit\Project2\EDA_OpenEnv_Agent\inference.py", line 19, in <module>
#     import pandas as pd
# ModuleNotFoundError: No module named 'pandas'

# %%
# !uv pip install pandas
# Out:
# 'uv' is not recognized as an internal or external command,
# operable program or batch file.
